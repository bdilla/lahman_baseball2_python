# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Be sure that Postgres/PGAdmin is launched

# establish a database connection
engine = create_engine("postgres+psycopg2://postgres:postgres@localhost:5432/lahman_baseball")
# Replace `<lahman_baseball_database_name>` with the actual name of your lahman baseball database as it appears in pgadmin

# use the connection to run a query using pandas!
batting_df = pd.read_sql("SELECT * FROM batting;", con=engine)
batting_df.head()
# Out:
#     playerid  yearid  stint teamid lgid   g   ab   r   h  h2b  ...   rbi   sb  \
# 0  abercda01    1871      1    TRO   NA   1    4   0   0    0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1   NA  25  118  30  32    6  ...  13.0  8.0
# 2  allisar01    1871      1    CL1   NA  29  137  28  40    4  ...  19.0  3.0
# 3  allisdo01    1871      1    WS3   NA  27  133  28  44   10  ...  27.0  1.0
# 4  ansonca01    1871      1    RC1   NA  25  120  29  39   11  ...  16.0  6.0
#
#     cs  bb   so  ibb  hbp  sh  sf  gidp
# 0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # College Table

# %%
collegeplayer_df = pd.read_sql("SELECT * FROM collegeplaying", con=engine)
collegeplayer_df.head()
# Out:
#     playerid schoolid  yearid
# 0  aardsda01   pennst    2001
# 1  aardsda01     rice    2002
# 2  aardsda01     rice    2003
# 3   abadan01  gamiddl    1992
# 4   abadan01  gamiddl    1993

# %% [markdown]
# # Vandy Table

# %%
vandy_df = collegeplayer_df[collegeplayer_df['schoolid'].str.contains('vandy')]
vandy_df
# Out:
#         playerid schoolid  yearid
# 232    alvarpe01    vandy    2006
# 233    alvarpe01    vandy    2007
# 234    alvarpe01    vandy    2008
# 895    baxtemi01    vandy    2004
# 896    baxtemi01    vandy    2005
# ...          ...      ...     ...
# 16806  willimi01    vandy    1970
# 16807  willimi01    vandy    1971
# 16808  willimi01    vandy    1972
# 17280   zeidjo01    vandy    2006
# 17281   zeidjo01    vandy    2007
#
# [65 rows x 3 columns]

# %%
vandy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65 entries, 232 to 17281
# Data columns (total 3 columns):
# playerid    65 non-null object
# schoolid    65 non-null object
# yearid      65 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# # People Table

# %%
people_df = pd.read_sql("SELECT * FROM people", con=engine)
people_df.head()
# Out:
#     playerid  birthyear  birthmonth  birthday birthcountry birthstate  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthcity  deathyear  deathmonth  deathday  ... namelast       namegiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile        NaN         NaN       NaN  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalgame   retroid    bbrefid
# 0  215.0   75.0    R      R  2004-04-06  2015-08-23  aardd001  aardsda01
# 1  180.0   72.0    R      R  1954-04-13  1976-10-03  aaroh101  aaronha01
# 2  190.0   75.0    R      R  1962-04-10  1971-09-26  aarot101  aaronto01
# 3  190.0   75.0    R      R  1977-07-26  1990-10-03  aased001   aasedo01
# 4  184.0   73.0    L      L  2001-09-10  2006-04-13  abada001   abadan01
#
# [5 rows x 24 columns]

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19112 entries, 0 to 19111
# Data columns (total 24 columns):
# playerid        19112 non-null object
# birthyear       18980 non-null float64
# birthmonth      18810 non-null float64
# birthday        18663 non-null float64
# birthcountry    19043 non-null object
# birthstate      18541 non-null object
# birthcity       18932 non-null object
# deathyear       9450 non-null float64
# deathmonth      9449 non-null float64
# deathday        9448 non-null float64
# deathcountry    9445 non-null object
# deathstate      9400 non-null object
# deathcity       9441 non-null object
# namefirst       19075 non-null object
# namelast        19112 non-null object
# namegiven       19075 non-null object
# weight          18261 non-null float64
# height          18330 non-null float64
# bats            17929 non-null object
# throws          18135 non-null object
# debut           18917 non-null object
# finalgame       18917 non-null object
# retroid         19049 non-null object
# bbrefid         19103 non-null object
# dtypes: float64(8), object(16)
# memory usage: 3.5+ MB

# %% [markdown]
# # Salary Table

# %%
salaries_df = pd.read_sql("SELECT * FROM salaries", con=engine)
salaries_df.head()
# Out:
#    yearid teamid lgid   playerid    salary
# 0    1985    ATL   NL  barkele01  870000.0
# 1    1985    ATL   NL  bedrost01  550000.0
# 2    1985    ATL   NL  benedbr01  545000.0
# 3    1985    ATL   NL   campri01  633333.0
# 4    1985    ATL   NL  ceronri01  625000.0

# %%
total_salaries_df = salaries_df.groupby('playerid')['salary'].sum().reset_index()
total_salaries_df
# Out:
#        playerid     salary
# 0     aardsda01  9259750.0
# 1      aasedo01  2300000.0
# 2      abadan01   327000.0
# 3      abadfe01  3766400.0
# 4     abbotje01   985000.0
# ...         ...        ...
# 5144  zumayjo01  4207000.0
# 5145  zuninmi01  1027600.0
# 5146  zupcibo01   431000.0
# 5147  zuvelpa01   145000.0
# 5148   zychto01   511000.0
#
# [5149 rows x 2 columns]

# %%
salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26428 entries, 0 to 26427
# Data columns (total 5 columns):
# yearid      26428 non-null int64
# teamid      26428 non-null object
# lgid        26428 non-null object
# playerid    26428 non-null object
# salary      26428 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# # Combining dataframes

# %%
vandy_people_df = pd.merge(vandy_df, people_df, how = 'left', on = 'playerid')
vandy_people_df
# Out:
#      playerid schoolid  yearid  birthyear  birthmonth  birthday birthcountry  \
# 0   alvarpe01    vandy    2006     1987.0         2.0       6.0         D.R.
# 1   alvarpe01    vandy    2007     1987.0         2.0       6.0         D.R.
# 2   alvarpe01    vandy    2008     1987.0         2.0       6.0         D.R.
# 3   baxtemi01    vandy    2004     1984.0        12.0       7.0          USA
# 4   baxtemi01    vandy    2005     1984.0        12.0       7.0          USA
# ..        ...      ...     ...        ...         ...       ...          ...
# 60  willimi01    vandy    1970     1950.0        12.0      26.0          USA
# 61  willimi01    vandy    1971     1950.0        12.0      26.0          USA
# 62  willimi01    vandy    1972     1950.0        12.0      26.0          USA
# 63   zeidjo01    vandy    2006     1987.0         3.0      24.0          USA
# 64   zeidjo01    vandy    2007     1987.0         3.0      24.0          USA
#
#            birthstate      birthcity  deathyear  ...  namelast  \
# 0   Distrito Nacional  Santo Domingo        NaN  ...   Alvarez
# 1   Distrito Nacional  Santo Domingo        NaN  ...   Alvarez
# 2   Distrito Nacional  Santo Domingo        NaN  ...   Alvarez
# 3                  NY         Queens        NaN  ...    Baxter
# 4                  NY         Queens        NaN  ...    Baxter
# ..                ...            ...        ...  ...       ...
# 60                 OK  Oklahoma City        NaN  ...    Willis
# 61                 OK  Oklahoma City        NaN  ...    Willis
# 62                 OK  Oklahoma City        NaN  ...    Willis
# 63                 CT      New Haven        NaN  ...      Zeid
# 64                 CT      New Haven        NaN  ...      Zeid
#
#            namegiven weight height bats throws       debut   finalgame  \
# 0       Pedro Manuel  250.0   75.0    L      R  2010-06-16  2016-10-01
# 1       Pedro Manuel  250.0   75.0    L      R  2010-06-16  2016-10-01
# 2       Pedro Manuel  250.0   75.0    L      R  2010-06-16  2016-10-01
# 3     Michael Joseph  205.0   72.0    L      R  2010-09-06  2015-07-08
# 4     Michael Joseph  205.0   72.0    L      R  2010-09-06  2015-07-08
# ..               ...    ...    ...  ...    ...         ...         ...
# 60     Michael Henry  205.0   74.0    L      L  1977-04-13  1981-06-11
# 61     Michael Henry  205.0   74.0    L      L  1977-04-13  1981-06-11
# 62     Michael Henry  205.0   74.0    L      L  1977-04-13  1981-06-11
# 63  Joshua Alexander  220.0   76.0    R      R  2013-07-30  2014-07-24
# 64  Joshua Alexander  220.0   76.0    R      R  2013-07-30  2014-07-24
#
#      retroid    bbrefid
# 0   alvap001  alvarpe01
# 1   alvap001  alvarpe01
# 2   alvap001  alvarpe01
# 3   baxtm001  baxtemi01
# 4   baxtm001  baxtemi01
# ..       ...        ...
# 60  willm101  willimi01
# 61  willm101  willimi01
# 62  willm101  willimi01
# 63  zeidj001   zeidjo01
# 64  zeidj001   zeidjo01
#
# [65 rows x 26 columns]

# %%
vandy_people_salaries_df = pd.merge(vandy_people_df, total_salaries_df, how = 'left', on = 'playerid')
vandy_people_salaries_df
# Out:
#      playerid schoolid  yearid  birthyear  birthmonth  birthday birthcountry  \
# 0   alvarpe01    vandy    2006     1987.0         2.0       6.0         D.R.
# 1   alvarpe01    vandy    2007     1987.0         2.0       6.0         D.R.
# 2   alvarpe01    vandy    2008     1987.0         2.0       6.0         D.R.
# 3   baxtemi01    vandy    2004     1984.0        12.0       7.0          USA
# 4   baxtemi01    vandy    2005     1984.0        12.0       7.0          USA
# ..        ...      ...     ...        ...         ...       ...          ...
# 60  willimi01    vandy    1970     1950.0        12.0      26.0          USA
# 61  willimi01    vandy    1971     1950.0        12.0      26.0          USA
# 62  willimi01    vandy    1972     1950.0        12.0      26.0          USA
# 63   zeidjo01    vandy    2006     1987.0         3.0      24.0          USA
# 64   zeidjo01    vandy    2007     1987.0         3.0      24.0          USA
#
#            birthstate      birthcity  deathyear  ...         namegiven  \
# 0   Distrito Nacional  Santo Domingo        NaN  ...      Pedro Manuel
# 1   Distrito Nacional  Santo Domingo        NaN  ...      Pedro Manuel
# 2   Distrito Nacional  Santo Domingo        NaN  ...      Pedro Manuel
# 3                  NY         Queens        NaN  ...    Michael Joseph
# 4                  NY         Queens        NaN  ...    Michael Joseph
# ..                ...            ...        ...  ...               ...
# 60                 OK  Oklahoma City        NaN  ...     Michael Henry
# 61                 OK  Oklahoma City        NaN  ...     Michael Henry
# 62                 OK  Oklahoma City        NaN  ...     Michael Henry
# 63                 CT      New Haven        NaN  ...  Joshua Alexander
# 64                 CT      New Haven        NaN  ...  Joshua Alexander
#
#     weight height bats throws       debut   finalgame   retroid    bbrefid  \
# 0    250.0   75.0    L      R  2010-06-16  2016-10-01  alvap001  alvarpe01
# 1    250.0   75.0    L      R  2010-06-16  2016-10-01  alvap001  alvarpe01
# 2    250.0   75.0    L      R  2010-06-16  2016-10-01  alvap001  alvarpe01
# 3    205.0   72.0    L      R  2010-09-06  2015-07-08  baxtm001  baxtemi01
# 4    205.0   72.0    L      R  2010-09-06  2015-07-08  baxtm001  baxtemi01
# ..     ...    ...  ...    ...         ...         ...       ...        ...
# 60   205.0   74.0    L      L  1977-04-13  1981-06-11  willm101  willimi01
# 61   205.0   74.0    L      L  1977-04-13  1981-06-11  willm101  willimi01
# 62   205.0   74.0    L      L  1977-04-13  1981-06-11  willm101  willimi01
# 63   220.0   76.0    R      R  2013-07-30  2014-07-24  zeidj001   zeidjo01
# 64   220.0   76.0    R      R  2013-07-30  2014-07-24  zeidj001   zeidjo01
#
#         salary
# 0   20681704.0
# 1   20681704.0
# 2   20681704.0
# 3    2094418.0
# 4    2094418.0
# ..         ...
# 60         NaN
# 61         NaN
# 62         NaN
# 63         NaN
# 64         NaN
#
# [65 rows x 27 columns]

# %%
vandy_people_salaries_df["Player Name"] = vandy_people_salaries_df["namefirst"] + " " + vandy_people_salaries_df["namelast"]
vandy_people_salaries_df
# Out:
#      playerid schoolid  yearid  birthyear  birthmonth  birthday birthcountry  \
# 0   alvarpe01    vandy    2006     1987.0         2.0       6.0         D.R.
# 1   alvarpe01    vandy    2007     1987.0         2.0       6.0         D.R.
# 2   alvarpe01    vandy    2008     1987.0         2.0       6.0         D.R.
# 3   baxtemi01    vandy    2004     1984.0        12.0       7.0          USA
# 4   baxtemi01    vandy    2005     1984.0        12.0       7.0          USA
# ..        ...      ...     ...        ...         ...       ...          ...
# 60  willimi01    vandy    1970     1950.0        12.0      26.0          USA
# 61  willimi01    vandy    1971     1950.0        12.0      26.0          USA
# 62  willimi01    vandy    1972     1950.0        12.0      26.0          USA
# 63   zeidjo01    vandy    2006     1987.0         3.0      24.0          USA
# 64   zeidjo01    vandy    2007     1987.0         3.0      24.0          USA
#
#            birthstate      birthcity  deathyear  ...  weight  height bats  \
# 0   Distrito Nacional  Santo Domingo        NaN  ...   250.0    75.0    L
# 1   Distrito Nacional  Santo Domingo        NaN  ...   250.0    75.0    L
# 2   Distrito Nacional  Santo Domingo        NaN  ...   250.0    75.0    L
# 3                  NY         Queens        NaN  ...   205.0    72.0    L
# 4                  NY         Queens        NaN  ...   205.0    72.0    L
# ..                ...            ...        ...  ...     ...     ...  ...
# 60                 OK  Oklahoma City        NaN  ...   205.0    74.0    L
# 61                 OK  Oklahoma City        NaN  ...   205.0    74.0    L
# 62                 OK  Oklahoma City        NaN  ...   205.0    74.0    L
# 63                 CT      New Haven        NaN  ...   220.0    76.0    R
# 64                 CT      New Haven        NaN  ...   220.0    76.0    R
#
#    throws       debut   finalgame   retroid    bbrefid      salary  \
# 0       R  2010-06-16  2016-10-01  alvap001  alvarpe01  20681704.0
# 1       R  2010-06-16  2016-10-01  alvap001  alvarpe01  20681704.0
# 2       R  2010-06-16  2016-10-01  alvap001  alvarpe01  20681704.0
# 3       R  2010-09-06  2015-07-08  baxtm001  baxtemi01   2094418.0
# 4       R  2010-09-06  2015-07-08  baxtm001  baxtemi01   2094418.0
# ..    ...         ...         ...       ...        ...         ...
# 60      L  1977-04-13  1981-06-11  willm101  willimi01         NaN
# 61      L  1977-04-13  1981-06-11  willm101  willimi01         NaN
# 62      L  1977-04-13  1981-06-11  willm101  willimi01         NaN
# 63      R  2013-07-30  2014-07-24  zeidj001   zeidjo01         NaN
# 64      R  2013-07-30  2014-07-24  zeidj001   zeidjo01         NaN
#
#       Player Name
# 0   Pedro Alvarez
# 1   Pedro Alvarez
# 2   Pedro Alvarez
# 3     Mike Baxter
# 4     Mike Baxter
# ..            ...
# 60    Mike Willis
# 61    Mike Willis
# 62    Mike Willis
# 63      Josh Zeid
# 64      Josh Zeid
#
# [65 rows x 28 columns]

# %%
##using grouby for counting

vandy_salaries_df = vandy_people_salaries_df.groupby('Player Name')['salary'].sum().reset_index()
vandy_salaries_df.columns = ['Player Name','salary']
vandy_salaries_df
# Out:
#           Player Name       salary
# 0   Antoan Richardson          0.0
# 1         David Price  245553888.0
# 2     Harvey Hendrick          0.0
# 3        Jensen Lewis    3702000.0
# 4       Jeremy Sowers    1154400.0
# 5           Joey Cora   16867500.0
# 6           Josh Paul    7920000.0
# 7           Josh Zeid          0.0
# 8            Mal Moss          0.0
# 9          Mark Prior   12800000.0
# 10          Matt Kata    3180000.0
# 11        Mike Baxter    4188836.0
# 12         Mike Minor   20512500.0
# 13        Mike Willis          0.0
# 14    Nick Christiani    2000000.0
# 15      Pedro Alvarez   62045112.0
# 16         Rip Sewell          0.0
# 17      Ryan Flaherty   12183000.0
# 18    Scott Sanderson   21500000.0
# 19     Scotti Madison     540000.0
# 20      Scrappy Moore          0.0
# 21         Slim Embry          0.0
# 22         Sonny Gray    4627500.0
# 23     Wilson Collins          0.0

# %%
vandy_salaries_df = vandy_salaries_df.sort_values('salary', ascending = False)
vandy_salaries_df
# Out:
#           Player Name       salary
# 1         David Price  245553888.0
# 15      Pedro Alvarez   62045112.0
# 18    Scott Sanderson   21500000.0
# 12         Mike Minor   20512500.0
# 5           Joey Cora   16867500.0
# 9          Mark Prior   12800000.0
# 17      Ryan Flaherty   12183000.0
# 6           Josh Paul    7920000.0
# 22         Sonny Gray    4627500.0
# 11        Mike Baxter    4188836.0
# 3        Jensen Lewis    3702000.0
# 10          Matt Kata    3180000.0
# 14    Nick Christiani    2000000.0
# 4       Jeremy Sowers    1154400.0
# 19     Scotti Madison     540000.0
# 21         Slim Embry          0.0
# 20      Scrappy Moore          0.0
# 0   Antoan Richardson          0.0
# 16         Rip Sewell          0.0
# 13        Mike Willis          0.0
# 8            Mal Moss          0.0
# 7           Josh Zeid          0.0
# 2     Harvey Hendrick          0.0
# 23     Wilson Collins          0.0

# %% [markdown]
# # Question 2

# %%
##read in table
fielding_df = pd.read_sql("SELECT * FROM fielding;", con=engine)
fielding_df.head()
# Out:
#     playerid  yearid  stint teamid lgid pos   g  gs  innouts  po     a     e  \
# 0  abercda01    1871      1    TRO   NA  SS   1 NaN      NaN   1   3.0   2.0
# 1   addybo01    1871      1    RC1   NA  2B  22 NaN      NaN  67  72.0  42.0
# 2   addybo01    1871      1    RC1   NA  SS   3 NaN      NaN   8  14.0   7.0
# 3  allisar01    1871      1    CL1   NA  2B   2 NaN      NaN   1   4.0   0.0
# 4  allisar01    1871      1    CL1   NA  OF  29 NaN      NaN  51   3.0   7.0
#
#     dp  pb  wp  sb  cs  zr
# 0  0.0 NaN NaN NaN NaN NaN
# 1  5.0 NaN NaN NaN NaN NaN
# 2  0.0 NaN NaN NaN NaN NaN
# 3  0.0 NaN NaN NaN NaN NaN
# 4  1.0 NaN NaN NaN NaN NaN

# %%
fielding2016_df = fielding_df[fielding_df.yearid == 2016]
fielding2016_df
# Out:
#          playerid  yearid  stint teamid lgid pos    g     gs  innouts    po  \
# 134862   abadfe01    2016      1    MIN   AL   P   39    0.0    102.0     0
# 134863   abadfe01    2016      2    BOS   AL   P   18    0.0     38.0     0
# 134864  abreujo02    2016      1    CHA   AL  1B  152  152.0   4067.0  1243
# 134865  achteaj01    2016      1    LAA   AL   P   27    0.0    113.0     2
# 134866  ackledu01    2016      1    NYA   AL  1B   13   10.0    255.0    80
# ...           ...     ...    ...    ...  ...  ..  ...    ...      ...   ...
# 136810  zobribe01    2016      1    CHN   NL  2B  119  113.0   2929.0   177
# 136811  zobribe01    2016      1    CHN   NL  OF   46   29.0    859.0    43
# 136812  zobribe01    2016      1    CHN   NL  SS    1    0.0      6.0     0
# 136813  zuninmi01    2016      1    SEA   AL   C   52   48.0   1331.0   400
# 136814   zychto01    2016      1    SEA   AL   P   12    0.0     41.0     0
#
#             a     e     dp   pb  wp    sb   cs  zr
# 134862    3.0   0.0    1.0  NaN NaN   NaN  NaN NaN
# 134863    1.0   0.0    0.0  NaN NaN   NaN  NaN NaN
# 134864   84.0  10.0  131.0  NaN NaN   NaN  NaN NaN
# 134865    4.0   0.0    0.0  NaN NaN   NaN  NaN NaN
# 134866    7.0   0.0    7.0  NaN NaN   NaN  NaN NaN
# ...       ...   ...    ...  ...  ..   ...  ...  ..
# 136810  250.0   7.0   52.0  NaN NaN   NaN  NaN NaN
# 136811    1.0   0.0    0.0  NaN NaN   NaN  NaN NaN
# 136812    0.0   0.0    0.0  NaN NaN   NaN  NaN NaN
# 136813   15.0   0.0    0.0  3.0 NaN  19.0  7.0 NaN
# 136814    0.0   1.0    0.0  NaN NaN   NaN  NaN NaN
#
# [1953 rows x 18 columns]

# %%
outfield2016_df = fielding2016_df[fielding2016_df.pos == 'OF']
print(outfield2016_df.po.sum())
# Out:
# 29560

# %%
fielding2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1953 entries, 134862 to 136814
# Data columns (total 18 columns):
# playerid    1953 non-null object
# yearid      1953 non-null int64
# stint       1953 non-null int64
# teamid      1953 non-null object
# lgid        1953 non-null object
# pos         1953 non-null object
# g           1953 non-null int64
# gs          1953 non-null float64
# innouts     1953 non-null float64
# po          1953 non-null int64
# a           1953 non-null float64
# e           1953 non-null float64
# dp          1953 non-null float64
# pb          114 non-null float64
# wp          0 non-null float64
# sb          114 non-null float64
# cs          114 non-null float64
# zr          0 non-null float64
# dtypes: float64(10), int64(4), object(4)
# memory usage: 289.9+ KB

# %%
infield2016_df = fielding2016_df[fielding2016_df.pos.isin(['SS', '1B', '2B', '3B'])]
print(infield2016_df.po.sum())
# Out:
# 58934

# %%
battery2016_df = fielding2016_df[fielding2016_df.pos.isin(['P', 'C'])]
print(battery2016_df.po.sum())
# Out:
# 41424

# %% [markdown]
# # Question 3

# %%
teams_df = pd.read_sql("SELECT * FROM teams;", con=engine)
teams_df.head()
# Out:
#    yearid lgid teamid franchid divid  rank   g  ghome   w   l  ...  dp     fp  \
# 0    1871   NA    BS1      BNA  None     3  31    NaN  20  10  ... NaN  0.838
# 1    1871   NA    CH1      CNA  None     2  28    NaN  19   9  ... NaN  0.829
# 2    1871   NA    CL1      CFC  None     8  29    NaN  10  19  ... NaN  0.814
# 3    1871   NA    FW1      KEK  None     7  19    NaN   7  12  ... NaN  0.803
# 4    1871   NA    NY2      NNA  None     5  33    NaN  16  17  ... NaN  0.839
#
#                       name                          park  attendance  bpf  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    ppf  teamidbr  teamidlahman45  teamidretro
# 0   98       BOS             BS1          BS1
# 1  102       CHI             CH1          CH1
# 2  100       CLE             CL1          CL1
# 3  107       KEK             FW1          FW1
# 4   88       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %%
new_teams_df = teams_df.drop(columns = ['lgid', 'franchid', 'divid','rank','g','ghome','divwin','wcwin','lgwin','r','ab','h','h2b','h3b','hr','bb','so','sb','cs','hbp','sf','ra','er','era','cg','sho','sv','ipouts','ha','hra','bba','soa','e','dp','fp','park','attendance','bpf','ppf','teamidbr','teamidlahman45','teamidretro'])
new_teams_df
# Out:
#       yearid teamid   w   l wswin                     name
# 0       1871    BS1  20  10  None     Boston Red Stockings
# 1       1871    CH1  19   9  None  Chicago White Stockings
# 2       1871    CL1  10  19  None   Cleveland Forest Citys
# 3       1871    FW1   7  12  None     Fort Wayne Kekiongas
# 4       1871    NY2  16  17  None         New York Mutuals
# ...      ...    ...  ..  ..   ...                      ...
# 2830    2016    SLN  86  76     N      St. Louis Cardinals
# 2831    2016    TBA  68  94     N           Tampa Bay Rays
# 2832    2016    TEX  95  67     N            Texas Rangers
# 2833    2016    TOR  89  73     N        Toronto Blue Jays
# 2834    2016    WAS  95  67     N     Washington Nationals
#
# [2835 rows x 6 columns]

# %% [markdown]
# # 3A

# %%
loser_teams_df = new_teams_df[(new_teams_df.yearid >= 1970) & (new_teams_df['wswin'] == 'N')]
print(loser_teams_df['wswin'])
# Out:
# 1541    N
# 1543    N
# 1544    N
# 1545    N
# 1546    N
#        ..
# 2830    N
# 2831    N
# 2832    N
# 2833    N
# 2834    N
# Name: wswin, Length: 1220, dtype: object

# %%
big_win_df = loser_teams_df.sort_values('w', ascending = False)
big_win_df
# Out:
#       yearid teamid    w   l wswin                 name
# 2379    2001    SEA  116  46     N     Seattle Mariners
# 2267    1998    ATL  106  56     N       Atlanta Braves
# 2471    2004    SLN  105  57     N  St. Louis Cardinals
# 2125    1993    ATL  104  58     N       Atlanta Braves
# 2012    1988    OAK  104  58     N    Oakland Athletics
# ...      ...    ...  ...  ..   ...                  ...
# 1825    1981    MIN   41  68     N      Minnesota Twins
# 1829    1981    NYN   41  62     N        New York Mets
# 1833    1981    SDN   41  69     N     San Diego Padres
# 1818    1981    CHN   38  65     N         Chicago Cubs
# 1838    1981    TOR   37  69     N    Toronto Blue Jays
#
# [1220 rows x 6 columns]

# %% [markdown]
# # 3B

# %%
winning_teams_df = new_teams_df[(new_teams_df.yearid >= 1970) & (new_teams_df['wswin'] == 'Y')]
print(winning_teams_df['wswin'])
# Out:
# 1542    Y
# 1584    Y
# 1606    Y
# 1630    Y
# 1654    Y
# 1667    Y
# 1691    Y
# 1724    Y
# 1750    Y
# 1780    Y
# 1805    Y
# 1824    Y
# 1862    Y
# 1866    Y
# 1899    Y
# 1927    Y
# 1959    Y
# 1981    Y
# 2006    Y
# 2038    Y
# 2053    Y
# 2085    Y
# 2124    Y
# 2152    Y
# 2181    Y
# 2226    Y
# 2247    Y
# 2283    Y
# 2313    Y
# 2343    Y
# 2356    Y
# 2385    Y
# 2426    Y
# 2449    Y
# 2479    Y
# 2530    Y
# 2538    Y
# 2585    Y
# 2612    Y
# 2649    Y
# 2680    Y
# 2709    Y
# 2718    Y
# 2769    Y
# 2786    Y
# 2810    Y
# Name: wswin, dtype: object

# %%
small_win_df = winning_teams_df.sort_values('w')
small_win_df
# Out:
#       yearid teamid    w   l wswin                   name
# 1824    1981    LAN   63  47     Y    Los Angeles Dodgers
# 2530    2006    SLN   83  78     Y    St. Louis Cardinals
# 1981    1987    MIN   85  77     Y        Minnesota Twins
# 2343    2000    NYA   87  74     Y       New York Yankees
# 2769    2014    SFN   88  74     Y   San Francisco Giants
# 1654    1974    OAK   90  72     Y      Oakland Athletics
# 2181    1995    ATL   90  54     Y         Atlanta Braves
# 2680    2011    SLN   90  72     Y    St. Louis Cardinals
# 2053    1990    CIN   91  71     Y        Cincinnati Reds
# 2426    2003    FLO   91  71     Y        Florida Marlins
# 1927    1985    KCA   91  71     Y     Kansas City Royals
# 1805    1980    PHI   91  71     Y  Philadelphia Phillies
# 2649    2010    SFN   92  70     Y   San Francisco Giants
# 2585    2008    PHI   92  70     Y  Philadelphia Phillies
# 1862    1982    SLN   92  70     Y    St. Louis Cardinals
# 2356    2001    ARI   92  70     Y   Arizona Diamondbacks
# 2247    1997    FLO   92  70     Y        Florida Marlins
# 2226    1996    NYA   92  70     Y       New York Yankees
# 1606    1972    OAK   93  62     Y      Oakland Athletics
# 2709    2012    SFN   94  68     Y   San Francisco Giants
# 1630    1973    OAK   94  68     Y      Oakland Athletics
# 2006    1988    LAN   94  67     Y    Los Angeles Dodgers
# 2085    1991    MIN   95  67     Y        Minnesota Twins
# 2786    2015    KCA   95  67     Y     Kansas City Royals
# 2152    1993    TOR   95  67     Y      Toronto Blue Jays
# 2538    2007    BOS   96  66     Y         Boston Red Sox
# 2124    1992    TOR   96  66     Y      Toronto Blue Jays
# 1584    1971    PIT   97  65     Y     Pittsburgh Pirates
# 2718    2013    BOS   97  65     Y         Boston Red Sox
# 1866    1983    BAL   98  64     Y      Baltimore Orioles
# 2313    1999    NYA   98  64     Y       New York Yankees
# 1780    1979    PIT   98  64     Y     Pittsburgh Pirates
# 2449    2004    BOS   98  64     Y         Boston Red Sox
# 2385    2002    ANA   99  63     Y         Anaheim Angels
# 2479    2005    CHA   99  63     Y      Chicago White Sox
# 2038    1989    OAK   99  63     Y      Oakland Athletics
# 1750    1978    NYA  100  63     Y       New York Yankees
# 1724    1977    NYA  100  62     Y       New York Yankees
# 1691    1976    CIN  102  60     Y        Cincinnati Reds
# 2810    2016    CHN  103  58     Y           Chicago Cubs
# 2612    2009    NYA  103  59     Y       New York Yankees
# 1899    1984    DET  104  58     Y         Detroit Tigers
# 1959    1986    NYN  108  54     Y          New York Mets
# 1667    1975    CIN  108  54     Y        Cincinnati Reds
# 1542    1970    BAL  108  54     Y      Baltimore Orioles
# 2283    1998    NYA  114  48     Y       New York Yankees

# %% [markdown]
# # 3C

# %% [markdown]
# # Question4

# %%
managers_df = pd.read_sql("SELECT * FROM managers;", con=engine)
managers_df.head()
# Out:
#     playerid  yearid teamid lgid  inseason   g   w   l  rank plyrmgr
# 0  wrighha01    1871    BS1   NA         1  31  20  10   3.0       Y
# 1   woodji01    1871    CH1   NA         1  28  19   9   2.0       Y
# 2  paborch01    1871    CL1   NA         1  29  10  19   8.0       Y
# 3  lennobi01    1871    FW1   NA         1  14   5   9   8.0       Y
# 4  deaneha01    1871    FW1   NA         2   5   2   3   8.0       Y

# %%
awards_managers_df = pd.read_sql("SELECT * FROM awardsmanagers;", con=engine)
awards_managers_df
# Out:
#       playerid                    awardid  yearid lgid   tie notes
# 0    larusto01  BBWAA Manager of the Year    1983   AL  None  None
# 1    lasorto01  BBWAA Manager of the Year    1983   NL  None  None
# 2    andersp01  BBWAA Manager of the Year    1984   AL  None  None
# 17   175.0    72.0     R      R  1980-09-01  1997-09-28  penat001   penato01
# 18   175.0    72.0     R      R  1981-09-01  1985-10-06  gardr001  gardero01
# 19   150.0    71.0     L      R  1985-04-09  2000-10-01  guilo001  guilloz01
# 20   175.0    71.0     R      R        None        None  leylj801  leylaji99
# 21   215.0    75.0     R      R  1991-10-05  1994-07-29  wedge001  wedgeer01
# 22   190.0    71.0     R      R        None        None  maddj801  maddojo99
# 23   200.0    74.0     L      R  1980-04-20  1992-10-02  sciom001  sciosmi01
# 24   175.0    72.0     R      R  1981-09-01  1985-10-06  gardr001  gardero01
# 25   190.0    71.0     R      R        None        None  maddj801  maddojo99
# 26   195.0    69.0     L      L        None        None  showb801  showabu99
# 27   210.0    76.0     R      R  1987-08-18  1996-05-22  farrj001  farrejo03
# 28   195.0    69.0     L      L        None        None  showb801  showabu99
# 29   185.0    72.0     R      R  1978-04-07  1998-09-27  molip001  molitpa01
#
# [30 rows x 29 columns]

# %%
nl_awards_managers_df = awards_managers_df[awards_managers_df['lgid'].str.contains('NL')]
nl_awards_managers_df
# Out:
#       playerid                    awardid  yearid lgid   tie notes
# 1    lasorto01  BBWAA Manager of the Year    1983   NL  None  None
# 3     freyji99  BBWAA Manager of the Year    1984   NL  None  None
# 5    herzowh01  BBWAA Manager of the Year    1985   NL  None  None
# 7    lanieha01  BBWAA Manager of the Year    1986   NL  None  None
# 9    rodgebu01  BBWAA Manager of the Year    1987   NL  None  None
# ..         ...                        ...     ...  ...   ...   ...
# 170  willima04    TSN Manager of the Year    2014   NL  None  None
# 172  collite99    TSN Manager of the Year    2015   NL  None  None
# 174  willima04  BBWAA Manager of the Year    2014   NL  None  None
# 176  maddojo99  BBWAA Manager of the Year    2015   NL  None  None
# 178  roberda07  BBWAA Manager of the Year    2016   NL  None  None
#
# [64 rows x 6 columns]

# %%
nltsn_awards_managers_df = nl_awards_managers_df[nl_awards_managers_df['awardid'].str.contains('TSN')]
nltsn_awards_managers_df
# Out:
#       playerid                  awardid  yearid lgid   tie notes
# 113  lanieha01  TSN Manager of the Year    1986   NL  None  None
# 116  rodgebu01  TSN Manager of the Year    1987   NL  None  None
# 118  leylaji99  TSN Manager of the Year    1988   NL  None  None
# 120  zimmedo01  TSN Manager of the Year    1989   NL  None  None
# 121  leylaji99  TSN Manager of the Year    1990   NL  None  None
# 123    coxbo01  TSN Manager of the Year    1991   NL  None  None
# 126  leylaji99  TSN Manager of the Year    1992   NL  None  None
# 127    coxbo01  TSN Manager of the Year    1993   NL  None  None
# 129   aloufe01  TSN Manager of the Year    1994   NL  None  None
# 131  baylodo01  TSN Manager of the Year    1995   NL  None  None
# 133  bochybr01  TSN Manager of the Year    1996   NL  None  None
# 135  bakerdu01  TSN Manager of the Year    1997   NL  None  None
# 137  bochybr01  TSN Manager of the Year    1998   NL  None  None
# 139    coxbo01  TSN Manager of the Year    1999   NL  None  None
# 141  bakerdu01  TSN Manager of the Year    2000   NL  None  None
# 143   bowala01  TSN Manager of the Year    2001   NL  None  None
# 145    coxbo01  TSN Manager of the Year    2002   NL  None  None
# 147    coxbo01  TSN Manager of the Year    2003   NL  None  None
# 149    coxbo01  TSN Manager of the Year    2004   NL  None  None
# 151    coxbo01  TSN Manager of the Year    2005   NL  None  None
# 153  girarjo01  TSN Manager of the Year    2006   NL  None  None
# 155  melvibo01  TSN Manager of the Year    2007   NL  None  None
# 158  gonzafr99  TSN Manager of the Year    2008   NL  None  None
# 160  tracyji01  TSN Manager of the Year    2009   NL  None  None
# 162  blackbu02  TSN Manager of the Year    2010   NL  None  None
# 164  gibsoki01  TSN Manager of the Year    2011   NL  None  None
# 166  johnsda02  TSN Manager of the Year    2012   NL  None  None
# 168  hurdlcl01  TSN Manager of the Year    2013   NL  None  None
# 170  willima04  TSN Manager of the Year    2014   NL  None  None
# 172  collite99  TSN Manager of the Year    2015   NL  None  None

# %%
people_df = pd.read_sql("SELECT * FROM people;", con=engine)
people_df.head()
# Out:
#     playerid  birthyear  birthmonth  birthday birthcountry birthstate  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthcity  deathyear  deathmonth  deathday  ... namelast       namegiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile        NaN         NaN       NaN  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalgame   retroid    bbrefid
# 0  215.0   75.0    R      R  2004-04-06  2015-08-23  aardd001  aardsda01
# 1  180.0   72.0    R      R  1954-04-13  1976-10-03  aaroh101  aaronha01
# 2  190.0   75.0    R      R  1962-04-10  1971-09-26  aarot101  aaronto01
# 3  190.0   75.0    R      R  1977-07-26  1990-10-03  aased001   aasedo01
# 4  184.0   73.0    L      L  2001-09-10  2006-04-13  abada001   abadan01
#
# [5 rows x 24 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-e5e94ce74ca0> in <module>
# ----> 1 people_df['namefirst'] & ['namelast']
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#    1319         #   integer dtypes.  Otherwise these are boolean ops
#    1320         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# -> 1321         res_values = na_op(self.values, ovalues)
#    1322         unfilled = self._constructor(res_values, index=self.index, name=res_name)
#    1323         filled = filler(unfilled)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1260                 x = ensure_object(x)
#    1261                 y = ensure_object(y)
# -> 1262                 result = libops.vec_binop(x, y, op)
#    1263             else:
#    1264                 # let null fall thru
#
# pandas\_libs\ops.pyx in pandas._libs.ops.vec_binop()
#
# ValueError: Arrays were different lengths: 19112 vs 1
